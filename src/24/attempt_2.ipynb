# %% [markdown]
# # Day 24 second attempt

# %%
import pandas as pd
from pathlib import Path
import io

# %%
# So it turns out that the input code repoeats itself every 18 instructions
program = Path("input.txt").read_text().splitlines()
chunks = []
for i in range(0,len(program),18):
    chunks.append(",".join(program[i:i+18]))
text = "\n".join(chunks)
df = pd.read_csv(io.StringIO(text), header=None)

# %%
df
# Out:
#        0        1        2         3         4          5        6        7   \
# 0   inp w  mul x 0  add x z  mod x 26   div z 1   add x 12  eql x w  eql x 0
# 1   inp w  mul x 0  add x z  mod x 26   div z 1   add x 11  eql x w  eql x 0
# 2   inp w  mul x 0  add x z  mod x 26   div z 1   add x 12  eql x w  eql x 0
# 3   inp w  mul x 0  add x z  mod x 26  div z 26   add x -3  eql x w  eql x 0
# 4   inp w  mul x 0  add x z  mod x 26   div z 1   add x 10  eql x w  eql x 0
# 5   inp w  mul x 0  add x z  mod x 26  div z 26   add x -9  eql x w  eql x 0
# 6   inp w  mul x 0  add x z  mod x 26   div z 1   add x 10  eql x w  eql x 0
# 7   inp w  mul x 0  add x z  mod x 26  div z 26   add x -7  eql x w  eql x 0
# 8   inp w  mul x 0  add x z  mod x 26  div z 26  add x -11  eql x w  eql x 0
# 9   inp w  mul x 0  add x z  mod x 26  div z 26   add x -4  eql x w  eql x 0
# 10  inp w  mul x 0  add x z  mod x 26   div z 1   add x 14  eql x w  eql x 0
# ...

# %% [markdown]
# Instructions 0, 4, 5, 15 are different for each piece of input
#
# Based on this idea, I wrote a new code generator that cached intermediate
# based on chunks of repetitive instructions.
#
# This gets me up to ~200K iterations per second, so about 25% better, but I really need
# a full 10x or more speedup....

# %%
from output_opt import eval_license
from itertools import product
from tqdm import tqdm

# %%
for serial in tqdm(product(range(9,0,-1), repeat=14)):
    result = eval_license(serial)
    if result:
        break
# Out:
# 2055185it [00:09, 214781.74it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/66/xy0kf9dj5ss_lvvhgvym6_2r0000gn/T/ipykernel_25420/1210619342.py in <module>
#       1 for serial in tqdm(product(range(9,0,-1), repeat=14)):
# ----> 2     result = eval_license(serial)
#       3     if result:
#       4         break
#
# ~/advent_2021/src/24/output_opt.py in eval_license(INPUTS)
#      75     w,x,y,z = func8(w,x,y,z,INPUT)
#      76     w,x,y,z = func4(w,x,y,z)
# ---> 77     INPUT = next(INPUT_ITERATOR)
#      78     w,x,y,z = func6(w,x,y,z,INPUT)
#      79     w,x,y,z = func3(w,x,y,z)
#
# KeyboardInterrupt:
